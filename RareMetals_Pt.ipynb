# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df_Plat = pd.read_csv('JOHNMATT-PLAT.csv')

# %%
df_Plat.head()
# Out:
#          Date  Hong Kong 8:30  Hong Kong 14:00  London 09:00  New York 9:30
# 0  2019-07-29           870.0            870.0         871.0            NaN
# 1  2019-07-26           873.0            869.0         870.0          869.0
# 2  2019-07-25           879.0            882.0         886.0          874.0
# 3  2019-07-24           859.0            862.0         863.0          872.0
# 4  2019-07-23           850.0            849.0         851.0          852.0

# %%
df_Plat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6955 entries, 0 to 6954
# Data columns (total 5 columns):
# Date               6955 non-null object
# Hong Kong 8:30     6588 non-null float64
# Hong Kong 14:00    6618 non-null float64
# London 09:00       6842 non-null float64
# New York 9:30      6768 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 271.8+ KB

# %%
df_Plat['Date'] = df_Plat['Date'].apply(pd.to_datetime)

# %%
df_Plat.index = df_Plat['Date']

# %%
plt.figure(figsize=(16,8))
plt.plot(df_Plat['New York 9:30'])
plt.ylabel('Price')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')
