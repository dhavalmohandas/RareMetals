# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df_Pd = pd.read_csv('JOHNMATT-PALL.csv')

# %%
df_Pd.head()
# Out:
#          Date  Hong Kong 8:30  Hong Kong 14:00  London 09:00  New York 9:30
# 0  2019-07-29          1536.0           1536.0        1540.0            NaN
# 1  2019-07-26          1537.0           1533.0        1539.0         1528.0
# 2  2019-07-25          1547.0           1551.0        1546.0         1535.0
# 3  2019-07-24          1530.0           1533.0        1536.0         1530.0
# 4  2019-07-23          1528.0           1527.0        1526.0         1527.0

# %%
df_Pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6953 entries, 0 to 6952
# Data columns (total 5 columns):
# Date               6953 non-null object
# Hong Kong 8:30     6586 non-null float64
# Hong Kong 14:00    6613 non-null float64
# London 09:00       6838 non-null float64
# New York 9:30      6766 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 271.7+ KB

# %%
df_Pd['Date'] = df_Pd['Date'].apply(pd.to_datetime)

# %%
df_Pd.index = df_Pd['Date']

# %%
plt.figure(figsize=(16,8))
plt.plot(df_Pd['New York 9:30'])
plt.ylabel('Price of Palladium')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')
